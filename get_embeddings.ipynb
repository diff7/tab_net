# %%
import torch
import numpy as np
import pandas as pd
from tqdm import tqdm

from tab_net import TabNet

from data_processor import ( PandasCatLoader, 
                             get_feature_sizes, 
                             LabelEnc)

from run_test import ( set_seed, 
                       na_imputer,
                       RealNormalizer,
                       data_processing, 
                       make_dataset)

# %% [markdown]
# ### SAVE LEARNED EMBEDDINGS

# %%
params = dict()
params['TARGET'] = 'isFraud'
params['embed_scaler'] = 1/1.6  # division value
params['embed_exponent'] = 0.65
params['min_embed_size'] = 2
params['net_type'] = 'embeddings'  #'linear'
params["layer_norm"] = False
params["batch_norm"] = True
params["mid_features"] = 512
params["num_residual"] = 2
params["drop_out"] = 0
params['out_size'] = 2
params['cat_th'] = 50
params['batch_size'] = 512
params['lr'] = 0.0004
params['tags'] = ['Tabular NET','Fraud']
params['drop_na'] = 0.6

# %%
TRAIN_PATH = '../../../data_main/fraud/TRAIN.csv'
VAL_PATH = '../../../data_main/fraud/VAL.csv'


set_seed(44)
    
train, val, params = data_processing(TRAIN_PATH, VAL_PATH, params)
train_set, val_set =  make_dataset(train, val, params, shuffle=False, batch_size=params['batch_size'])
# Out:
# Nan in card2 555, imputing ...
# Nan in card3 110, imputing ...
# Nan in card5 609, imputing ...
# Nan in addr1 36328, imputing ...
# Nan in addr2 36328, imputing ...
# Nan in D1 129, imputing ...
# Nan in D4 47618, imputing ...
# Nan in D6 46194, imputing ...
# Nan in D8 41815, imputing ...
# Nan in D9 41815, imputing ...
# Nan in D10 45091, imputing ...
# Nan in D12 51257, imputing ...
# Nan in D13 49384, imputing ...
# Nan in D14 49154, imputing ...
# Nan in D15 45605, imputing ...
# Nan in V12 45121, imputing ...
# Nan in V13 45121, imputing ...
# Nan in V14 45121, imputing ...
# Nan in V15 45121, imputing ...
# Nan in V16 45121, imputing ...
# Nan in V17 45121, imputing ...
# Nan in V18 45121, imputing ...
# Nan in V19 45121, imputing ...
# Nan in V20 45121, imputing ...
# Nan in V21 45121, imputing ...
# Nan in V22 45121, imputing ...
# Nan in V23 45121, imputing ...
# Nan in V24 45121, imputing ...
# Nan in V25 45121, imputing ...
# Nan in V26 45121, imputing ...
# Nan in V27 45121, imputing ...
# Nan in V28 45121, imputing ...
# Nan in V29 45121, imputing ...
# Nan in V30 45121, imputing ...
# Nan in V31 45121, imputing ...
# Nan in V32 45121, imputing ...
# Nan in V33 45121, imputing ...
# Nan in V34 45121, imputing ...
# Nan in V35 47631, imputing ...
# Nan in V36 47631, imputing ...
# Nan in V37 47631, imputing ...
# Nan in V38 47631, imputing ...
# Nan in V39 47631, imputing ...
# Nan in V40 47631, imputing ...
# Nan in V41 47631, imputing ...
# Nan in V42 47631, imputing ...
# Nan in V43 47631, imputing ...
# Nan in V44 47631, imputing ...
# Nan in V45 47631, imputing ...
# Nan in V46 47631, imputing ...
# Nan in V47 47631, imputing ...
# Nan in V48 47631, imputing ...
# Nan in V49 47631, imputing ...
# Nan in V50 47631, imputing ...
# Nan in V51 47631, imputing ...
# Nan in V52 47631, imputing ...
# Nan in V53 46074, imputing ...
# Nan in V54 46074, imputing ...
# Nan in V55 46074, imputing ...
# Nan in V56 46074, imputing ...
# Nan in V57 46074, imputing ...
# Nan in V58 46074, imputing ...
# Nan in V59 46074, imputing ...
# Nan in V60 46074, imputing ...
# Nan in V61 46074, imputing ...
# Nan in V62 46074, imputing ...
# Nan in V63 46074, imputing ...
# Nan in V64 46074, imputing ...
# Nan in V65 46074, imputing ...
# Nan in V66 46074, imputing ...
# Nan in V67 46074, imputing ...
# Nan in V68 46074, imputing ...
# Nan in V69 46074, imputing ...
# Nan in V70 46074, imputing ...
# Nan in V71 46074, imputing ...
# Nan in V72 46074, imputing ...
# Nan in V73 46074, imputing ...
# Nan in V74 46074, imputing ...
# Nan in V75 45635, imputing ...
# Nan in V76 45635, imputing ...
# Nan in V77 45635, imputing ...
# Nan in V78 45635, imputing ...
# Nan in V79 45635, imputing ...
# Nan in V80 45635, imputing ...
# Nan in V81 45635, imputing ...
# Nan in V82 45635, imputing ...
# Nan in V83 45635, imputing ...
# Nan in V84 45635, imputing ...
# Nan in V85 45635, imputing ...
# Nan in V86 45635, imputing ...
# Nan in V87 45635, imputing ...
# Nan in V88 45635, imputing ...
# Nan in V89 45635, imputing ...
# Nan in V90 45635, imputing ...
# Nan in V91 45635, imputing ...
# Nan in V92 45635, imputing ...
# Nan in V93 45635, imputing ...
# Nan in V94 45635, imputing ...
# Nan in V95 37, imputing ...
# Nan in V96 37, imputing ...
# Nan in V97 37, imputing ...
# Nan in V98 37, imputing ...
# Nan in V99 37, imputing ...
# Nan in V100 37, imputing ...
# Nan in V101 37, imputing ...
# Nan in V102 37, imputing ...
# Nan in V103 37, imputing ...
# Nan in V104 37, imputing ...
# Nan in V105 37, imputing ...
# Nan in V106 37, imputing ...
# Nan in V107 37, imputing ...
# Nan in V108 37, imputing ...
# Nan in V109 37, imputing ...
# Nan in V110 37, imputing ...
# Nan in V111 37, imputing ...
# Nan in V112 37, imputing ...
# Nan in V113 37, imputing ...
# Nan in V114 37, imputing ...
# Nan in V115 37, imputing ...
# Nan in V116 37, imputing ...
# Nan in V117 37, imputing ...
# Nan in V118 37, imputing ...
# Nan in V119 37, imputing ...
# Nan in V120 37, imputing ...
# Nan in V121 37, imputing ...
# Nan in V122 37, imputing ...
# Nan in V123 37, imputing ...
# Nan in V124 37, imputing ...
# Nan in V125 37, imputing ...
# Nan in V126 37, imputing ...
# Nan in V127 37, imputing ...
# Nan in V128 37, imputing ...
# Nan in V129 37, imputing ...
# Nan in V130 37, imputing ...
# Nan in V131 37, imputing ...
# Nan in V132 37, imputing ...
# Nan in V133 37, imputing ...
# Nan in V134 37, imputing ...
# Nan in V135 37, imputing ...
# Nan in V136 37, imputing ...
# Nan in V137 37, imputing ...
# Nan in V138 37642, imputing ...
# Nan in V139 37642, imputing ...
# Nan in V140 37642, imputing ...
# Nan in V141 37642, imputing ...
# Nan in V142 37642, imputing ...
# Nan in V143 37638, imputing ...
# Nan in V144 37638, imputing ...
# Nan in V145 37638, imputing ...
# Nan in V146 37642, imputing ...
# Nan in V147 37642, imputing ...
# Nan in V148 37642, imputing ...
# Nan in V149 37642, imputing ...
# Nan in V150 37638, imputing ...
# Nan in V151 37638, imputing ...
# Nan in V152 37638, imputing ...
# Nan in V153 37642, imputing ...
# Nan in V154 37642, imputing ...
# Nan in V155 37642, imputing ...
# Nan in V156 37642, imputing ...
# Nan in V157 37642, imputing ...
# Nan in V158 37642, imputing ...
# Nan in V159 37638, imputing ...
# Nan in V160 37638, imputing ...
# Nan in V161 37642, imputing ...
# Nan in V162 37642, imputing ...
# Nan in V163 37642, imputing ...
# Nan in V164 37638, imputing ...
# Nan in V165 37638, imputing ...
# Nan in V166 37638, imputing ...
# Nan in V167 2745, imputing ...
# Nan in V168 2745, imputing ...
# Nan in V169 2619, imputing ...
# Nan in V170 2619, imputing ...
# Nan in V171 2619, imputing ...
# Nan in V172 2745, imputing ...
# Nan in V173 2745, imputing ...
# Nan in V174 2619, imputing ...
# Nan in V175 2619, imputing ...
# Nan in V176 2745, imputing ...
# Nan in V177 2745, imputing ...
# Nan in V178 2745, imputing ...
# Nan in V179 2745, imputing ...
# Nan in V180 2619, imputing ...
# Nan in V181 2745, imputing ...
# Nan in V182 2745, imputing ...
# Nan in V183 2745, imputing ...
# Nan in V184 2619, imputing ...
# Nan in V185 2619, imputing ...
# Nan in V186 2745, imputing ...
# Nan in V187 2745, imputing ...
# Nan in V188 2619, imputing ...
# Nan in V189 2619, imputing ...
# Nan in V190 2745, imputing ...
# Nan in V191 2745, imputing ...
# Nan in V192 2745, imputing ...
# Nan in V193 2745, imputing ...
# Nan in V194 2619, imputing ...
# Nan in V195 2619, imputing ...
# Nan in V196 2745, imputing ...
# Nan in V197 2619, imputing ...
# Nan in V198 2619, imputing ...
# Nan in V199 2745, imputing ...
# Nan in V200 2619, imputing ...
# Nan in V201 2619, imputing ...
# Nan in V202 2745, imputing ...
# Nan in V203 2745, imputing ...
# Nan in V204 2745, imputing ...
# Nan in V205 2745, imputing ...
# Nan in V206 2745, imputing ...
# Nan in V207 2745, imputing ...
# Nan in V208 2619, imputing ...
# Nan in V209 2619, imputing ...
# Nan in V210 2619, imputing ...
# Nan in V211 2745, imputing ...
# Nan in V212 2745, imputing ...
# Nan in V213 2745, imputing ...
# Nan in V214 2745, imputing ...
# Nan in V215 2745, imputing ...
# Nan in V216 2745, imputing ...
# Nan in V217 8301, imputing ...
# Nan in V218 8301, imputing ...
# Nan in V219 8301, imputing ...
# Nan in V220 1846, imputing ...
# Nan in V221 1846, imputing ...
# Nan in V222 1846, imputing ...
# Nan in V223 8301, imputing ...
# Nan in V224 8301, imputing ...
# Nan in V225 8301, imputing ...
# Nan in V226 8301, imputing ...
# Nan in V227 1846, imputing ...
# Nan in V228 8301, imputing ...
# Nan in V229 8301, imputing ...
# Nan in V230 8301, imputing ...
# Nan in V231 8301, imputing ...
# Nan in V232 8301, imputing ...
# Nan in V233 8301, imputing ...
# Nan in V234 1846, imputing ...
# Nan in V235 8301, imputing ...
# Nan in V236 8301, imputing ...
# Nan in V237 8301, imputing ...
# Nan in V238 1846, imputing ...
# Nan in V239 1846, imputing ...
# Nan in V240 8301, imputing ...
# Nan in V241 8301, imputing ...
# Nan in V242 8301, imputing ...
# Nan in V243 8301, imputing ...
# Nan in V244 8301, imputing ...
# Nan in V245 1846, imputing ...
# Nan in V246 8301, imputing ...
# Nan in V247 8301, imputing ...
# Nan in V248 8301, imputing ...
# Nan in V249 8301, imputing ...
# Nan in V250 1846, imputing ...
# Nan in V251 1846, imputing ...
# Nan in V252 8301, imputing ...
# Nan in V253 8301, imputing ...
# Nan in V254 8301, imputing ...
# Nan in V255 1846, imputing ...
# Nan in V256 1846, imputing ...
# Nan in V257 8301, imputing ...
# Nan in V258 8301, imputing ...
# Nan in V259 1846, imputing ...
# Nan in V260 8301, imputing ...
# Nan in V261 8301, imputing ...
# Nan in V262 8301, imputing ...
# Nan in V263 8301, imputing ...
# Nan in V264 8301, imputing ...
# Nan in V265 8301, imputing ...
# Nan in V266 8301, imputing ...
# Nan in V267 8301, imputing ...
# Nan in V268 8301, imputing ...
# Nan in V269 8301, imputing ...
# Nan in V270 1846, imputing ...
# Nan in V271 1846, imputing ...
# Nan in V272 1846, imputing ...
# Nan in V273 8301, imputing ...
# Nan in V274 8301, imputing ...
# Nan in V275 8301, imputing ...
# Nan in V276 8301, imputing ...
# Nan in V277 8301, imputing ...
# Nan in V278 8301, imputing ...
# Nan in V281 129, imputing ...
# Nan in V282 129, imputing ...
# Nan in V283 129, imputing ...
# Nan in V288 129, imputing ...
# Nan in V289 129, imputing ...
# Nan in V296 129, imputing ...
# Nan in V300 129, imputing ...
# Nan in V301 129, imputing ...
# Nan in V313 129, imputing ...
# Nan in V314 129, imputing ...
# Nan in V315 129, imputing ...
# Nan in V322 37390, imputing ...
# Nan in V323 37390, imputing ...
# Nan in V324 37390, imputing ...
# Nan in V325 37390, imputing ...
# Nan in V326 37390, imputing ...
# Nan in V327 37390, imputing ...
# Nan in V328 37390, imputing ...
# Nan in V329 37390, imputing ...
# Nan in V330 37390, imputing ...
# Nan in V331 37390, imputing ...
# Nan in V332 37390, imputing ...
# Nan in V333 37390, imputing ...
# Nan in V334 37390, imputing ...
# Nan in V335 37390, imputing ...
# Nan in V336 37390, imputing ...
# Nan in V337 37390, imputing ...
# Nan in V338 37390, imputing ...
# Nan in V339 37390, imputing ...
# Nan in id_02 1994, imputing ...
# Nan in id_03 46983, imputing ...
# Nan in id_04 46983, imputing ...
# Nan in id_05 4376, imputing ...
# Nan in id_06 4376, imputing ...
# Nan in id_09 41815, imputing ...
# Nan in id_10 41815, imputing ...
# Nan in id_11 1933, imputing ...
# Nan in id_13 10086, imputing ...
# Nan in id_14 38618, imputing ...
# Nan in id_17 2921, imputing ...
# Nan in id_19 2951, imputing ...
# Nan in id_20 2985, imputing ...
# Nan in id_32 40081, imputing ...
# Nan in card2 169, imputing ...
# Nan in card3 34, imputing ...
# Nan in card5 179, imputing ...
# Nan in addr1 12088, imputing ...
# Nan in addr2 12088, imputing ...
# Nan in D1 37, imputing ...
# Nan in D4 15945, imputing ...
# Nan in D6 15353, imputing ...
# Nan in D8 13839, imputing ...
# Nan in D9 13839, imputing ...
# Nan in D10 14985, imputing ...
# Nan in D12 17061, imputing ...
# Nan in D13 16453, imputing ...
# Nan in D14 16440, imputing ...
# Nan in D15 15179, imputing ...
# Nan in V12 14998, imputing ...
# Nan in V13 14998, imputing ...
# Nan in V14 14998, imputing ...
# Nan in V15 14998, imputing ...
# Nan in V16 14998, imputing ...
# Nan in V17 14998, imputing ...
# Nan in V18 14998, imputing ...
# Nan in V19 14998, imputing ...
# Nan in V20 14998, imputing ...
# Nan in V21 14998, imputing ...
# Nan in V22 14998, imputing ...
# Nan in V23 14998, imputing ...
# Nan in V24 14998, imputing ...
# Nan in V25 14998, imputing ...
# Nan in V26 14998, imputing ...
# Nan in V27 14998, imputing ...
# Nan in V28 14998, imputing ...
# Nan in V29 14998, imputing ...
# Nan in V30 14998, imputing ...
# Nan in V31 14998, imputing ...
# Nan in V32 14998, imputing ...
# Nan in V33 14998, imputing ...
# Nan in V34 14998, imputing ...
# Nan in V35 15951, imputing ...
# Nan in V36 15951, imputing ...
# Nan in V37 15951, imputing ...
# Nan in V38 15951, imputing ...
# Nan in V39 15951, imputing ...
# Nan in V40 15951, imputing ...
# Nan in V41 15951, imputing ...
# Nan in V42 15951, imputing ...
# Nan in V43 15951, imputing ...
# Nan in V44 15951, imputing ...
# Nan in V45 15951, imputing ...
# Nan in V46 15951, imputing ...
# Nan in V47 15951, imputing ...
# Nan in V48 15951, imputing ...
# Nan in V49 15951, imputing ...
# Nan in V50 15951, imputing ...
# Nan in V51 15951, imputing ...
# Nan in V52 15951, imputing ...
# Nan in V53 15230, imputing ...
# Nan in V54 15230, imputing ...
# Nan in V55 15230, imputing ...
# Nan in V56 15230, imputing ...
# Nan in V57 15230, imputing ...
# Nan in V58 15230, imputing ...
# Nan in V59 15230, imputing ...
# Nan in V60 15230, imputing ...
# Nan in V61 15230, imputing ...
# Nan in V62 15230, imputing ...
# Nan in V63 15230, imputing ...
# Nan in V64 15230, imputing ...
# Nan in V65 15230, imputing ...
# Nan in V66 15230, imputing ...
# Nan in V67 15230, imputing ...
# Nan in V68 15230, imputing ...
# Nan in V69 15230, imputing ...
# Nan in V70 15230, imputing ...
# Nan in V71 15230, imputing ...
# Nan in V72 15230, imputing ...
# Nan in V73 15230, imputing ...
# Nan in V74 15230, imputing ...
# Nan in V75 15194, imputing ...
# Nan in V76 15194, imputing ...
# Nan in V77 15194, imputing ...
# Nan in V78 15194, imputing ...
# Nan in V79 15194, imputing ...
# Nan in V80 15194, imputing ...
# Nan in V81 15194, imputing ...
# Nan in V82 15194, imputing ...
# Nan in V83 15194, imputing ...
# Nan in V84 15194, imputing ...
# Nan in V85 15194, imputing ...
# Nan in V86 15194, imputing ...
# Nan in V87 15194, imputing ...
# Nan in V88 15194, imputing ...
# Nan in V89 15194, imputing ...
# Nan in V90 15194, imputing ...
# Nan in V91 15194, imputing ...
# Nan in V92 15194, imputing ...
# Nan in V93 15194, imputing ...
# Nan in V94 15194, imputing ...
# Nan in V95 13, imputing ...
# Nan in V96 13, imputing ...
# Nan in V97 13, imputing ...
# Nan in V98 13, imputing ...
# Nan in V99 13, imputing ...
# Nan in V100 13, imputing ...
# Nan in V101 13, imputing ...
# Nan in V102 13, imputing ...
# Nan in V103 13, imputing ...
# Nan in V104 13, imputing ...
# Nan in V105 13, imputing ...
# Nan in V106 13, imputing ...
# Nan in V107 13, imputing ...
# Nan in V108 13, imputing ...
# Nan in V109 13, imputing ...
# Nan in V110 13, imputing ...
# Nan in V111 13, imputing ...
# Nan in V112 13, imputing ...
# Nan in V113 13, imputing ...
# Nan in V114 13, imputing ...
# Nan in V115 13, imputing ...
# Nan in V116 13, imputing ...
# Nan in V117 13, imputing ...
# Nan in V118 13, imputing ...
# Nan in V119 13, imputing ...
# Nan in V120 13, imputing ...
# Nan in V121 13, imputing ...
# Nan in V122 13, imputing ...
# Nan in V123 13, imputing ...
# Nan in V124 13, imputing ...
# Nan in V125 13, imputing ...
# Nan in V126 13, imputing ...
# Nan in V127 13, imputing ...
# Nan in V128 13, imputing ...
# Nan in V129 13, imputing ...
# Nan in V130 13, imputing ...
# Nan in V131 13, imputing ...
# Nan in V132 13, imputing ...
# Nan in V133 13, imputing ...
# Nan in V134 13, imputing ...
# Nan in V135 13, imputing ...
# Nan in V136 13, imputing ...
# Nan in V137 13, imputing ...
# Nan in V138 12485, imputing ...
# Nan in V139 12485, imputing ...
# Nan in V140 12485, imputing ...
# Nan in V141 12485, imputing ...
# Nan in V142 12485, imputing ...
# Nan in V143 12485, imputing ...
# Nan in V144 12485, imputing ...
# Nan in V145 12485, imputing ...
# Nan in V146 12485, imputing ...
# Nan in V147 12485, imputing ...
# Nan in V148 12485, imputing ...
# Nan in V149 12485, imputing ...
# Nan in V150 12485, imputing ...
# Nan in V151 12485, imputing ...
# Nan in V152 12485, imputing ...
# Nan in V153 12485, imputing ...
# Nan in V154 12485, imputing ...
# Nan in V155 12485, imputing ...
# Nan in V156 12485, imputing ...
# Nan in V157 12485, imputing ...
# Nan in V158 12485, imputing ...
# Nan in V159 12485, imputing ...
# Nan in V160 12485, imputing ...
# Nan in V161 12485, imputing ...
# Nan in V162 12485, imputing ...
# Nan in V163 12485, imputing ...
# Nan in V164 12485, imputing ...
# Nan in V165 12485, imputing ...
# Nan in V166 12485, imputing ...
# Nan in V167 895, imputing ...
# Nan in V168 895, imputing ...
# Nan in V169 856, imputing ...
# Nan in V170 856, imputing ...
# Nan in V171 856, imputing ...
# Nan in V172 895, imputing ...
# Nan in V173 895, imputing ...
# Nan in V174 856, imputing ...
# Nan in V175 856, imputing ...
# Nan in V176 895, imputing ...
# Nan in V177 895, imputing ...
# Nan in V178 895, imputing ...
# Nan in V179 895, imputing ...
# Nan in V180 856, imputing ...
# Nan in V181 895, imputing ...
# Nan in V182 895, imputing ...
# Nan in V183 895, imputing ...
# Nan in V184 856, imputing ...
# Nan in V185 856, imputing ...
# Nan in V186 895, imputing ...
# Nan in V187 895, imputing ...
# Nan in V188 856, imputing ...
# Nan in V189 856, imputing ...
# Nan in V190 895, imputing ...
# Nan in V191 895, imputing ...
# Nan in V192 895, imputing ...
# Nan in V193 895, imputing ...
# Nan in V194 856, imputing ...
# Nan in V195 856, imputing ...
# Nan in V196 895, imputing ...
# Nan in V197 856, imputing ...
# Nan in V198 856, imputing ...
# Nan in V199 895, imputing ...
# Nan in V200 856, imputing ...
# Nan in V201 856, imputing ...
# Nan in V202 895, imputing ...
# Nan in V203 895, imputing ...
# Nan in V204 895, imputing ...
# Nan in V205 895, imputing ...
# Nan in V206 895, imputing ...
# Nan in V207 895, imputing ...
# Nan in V208 856, imputing ...
# Nan in V209 856, imputing ...
# Nan in V210 856, imputing ...
# Nan in V211 895, imputing ...
# Nan in V212 895, imputing ...
# Nan in V213 895, imputing ...
# Nan in V214 895, imputing ...
# Nan in V215 895, imputing ...
# Nan in V216 895, imputing ...
# Nan in V217 2807, imputing ...
# Nan in V218 2807, imputing ...
# Nan in V219 2807, imputing ...
# Nan in V220 615, imputing ...
# Nan in V221 615, imputing ...
# Nan in V222 615, imputing ...
# Nan in V223 2807, imputing ...
# Nan in V224 2807, imputing ...
# Nan in V225 2807, imputing ...
# Nan in V226 2807, imputing ...
# Nan in V227 615, imputing ...
# Nan in V228 2807, imputing ...
# Nan in V229 2807, imputing ...
# Nan in V230 2807, imputing ...
# Nan in V231 2807, imputing ...
# Nan in V232 2807, imputing ...
# Nan in V233 2807, imputing ...
# Nan in V234 615, imputing ...
# Nan in V235 2807, imputing ...
# Nan in V236 2807, imputing ...
# Nan in V237 2807, imputing ...
# Nan in V238 615, imputing ...
# Nan in V239 615, imputing ...
# Nan in V240 2807, imputing ...
# Nan in V241 2807, imputing ...
# Nan in V242 2807, imputing ...
# Nan in V243 2807, imputing ...
# Nan in V244 2807, imputing ...
# Nan in V245 615, imputing ...
# Nan in V246 2807, imputing ...
# Nan in V247 2807, imputing ...
# Nan in V248 2807, imputing ...
# Nan in V249 2807, imputing ...
# Nan in V250 615, imputing ...
# Nan in V251 615, imputing ...
# Nan in V252 2807, imputing ...
# Nan in V253 2807, imputing ...
# Nan in V254 2807, imputing ...
# Nan in V255 615, imputing ...
# Nan in V256 615, imputing ...
# Nan in V257 2807, imputing ...
# Nan in V258 2807, imputing ...
# Nan in V259 615, imputing ...
# Nan in V260 2807, imputing ...
# Nan in V261 2807, imputing ...
# Nan in V262 2807, imputing ...
# Nan in V263 2807, imputing ...
# Nan in V264 2807, imputing ...
# Nan in V265 2807, imputing ...
# Nan in V266 2807, imputing ...
# Nan in V267 2807, imputing ...
# Nan in V268 2807, imputing ...
# Nan in V269 2807, imputing ...
# Nan in V270 615, imputing ...
# Nan in V271 615, imputing ...
# Nan in V272 615, imputing ...
# Nan in V273 2807, imputing ...
# Nan in V274 2807, imputing ...
# Nan in V275 2807, imputing ...
# Nan in V276 2807, imputing ...
# Nan in V277 2807, imputing ...
# Nan in V278 2807, imputing ...
# Nan in V281 37, imputing ...
# Nan in V282 37, imputing ...
# Nan in V283 37, imputing ...
# Nan in V288 37, imputing ...
# Nan in V289 37, imputing ...
# Nan in V296 37, imputing ...
# Nan in V300 37, imputing ...
# Nan in V301 37, imputing ...
# Nan in V313 37, imputing ...
# Nan in V314 37, imputing ...
# Nan in V315 37, imputing ...
# Nan in V322 12420, imputing ...
# Nan in V323 12420, imputing ...
# Nan in V324 12420, imputing ...
# Nan in V325 12420, imputing ...
# Nan in V326 12420, imputing ...
# Nan in V327 12420, imputing ...
# Nan in V328 12420, imputing ...
# Nan in V329 12420, imputing ...
# Nan in V330 12420, imputing ...
# Nan in V331 12420, imputing ...
# Nan in V332 12420, imputing ...
# Nan in V333 12420, imputing ...
# Nan in V334 12420, imputing ...
# Nan in V335 12420, imputing ...
# Nan in V336 12420, imputing ...
# Nan in V337 12420, imputing ...
# Nan in V338 12420, imputing ...
# Nan in V339 12420, imputing ...
# Nan in id_02 662, imputing ...
# Nan in id_03 15564, imputing ...
# Nan in id_04 15564, imputing ...
# Nan in id_05 1501, imputing ...
# Nan in id_06 1501, imputing ...
# Nan in id_09 13839, imputing ...
# Nan in id_10 13839, imputing ...
# Nan in id_11 638, imputing ...
# Nan in id_13 3411, imputing ...
# Nan in id_14 12789, imputing ...
# Nan in id_17 944, imputing ...
# Nan in id_19 959, imputing ...
# Nan in id_20 965, imputing ...
# Nan in id_32 13297, imputing ...
# Low variance items all: 548, Objects all: 21
# Low variance objects: 15, High var objects: 6

# %%
train.shape
# Out:
# (86701, 705)

# %%
train.shape
# Out:
# (89957, 13)

# %%
PATH = 'Tabular NET Fraud embeddings _Fraud.pth'
model = TabNet(params)
model.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
params
# Out:
# {'TARGET': 'isFraud',
#  'embed_scaler': 0.625,
#  'embed_exponent': 0.65,
#  'min_embed_size': 4,
#  'net_type': 'embedidings',
#  'layer_norm': False,
#  'batch_norm': True,
#  'mid_features': 512,
#  'num_residual': 2,
#  'drop_out': 0,
#  'out_size': 2,
#  'cat_th': 100,
#  'batch_size': 512,
#  'lr': 0.004,
#  'tags': ['Tabular NET', 'Fraud'],
#  'drop_na': 0.7,
#  'real_features_size': 136,
#  'num_categoical': 586,
#  'cat_embed_sizes': {'V17_col_na_binary': {'embedding_dim': 4,
#    'num_categories': 2},
#   'D9_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V48_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V178_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V223_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V203_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V155': {'embedding_dim': 11, 'num_categories': 22},
#   'V236_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V18_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V92_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V80_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V30': {'embedding_dim': 4, 'num_categories': 2},
#   'V51': {'embedding_dim': 5, 'num_categories': 8},
#   'V122': {'embedding_dim': 4, 'num_categories': 4},
#   'V176': {'embedding_dim': 20, 'num_categories': 50},
#   'card3': {'embedding_dim': 30, 'num_categories': 94},
#   'V63': {'embedding_dim': 6, 'num_categories': 9},
#   'V35_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_34': {'embedding_dim': 4, 'num_categories': 5},
#   'V137_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_17': {'embedding_dim': 30, 'num_categories': 95},
#   'V247_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_02_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V109_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V156': {'embedding_dim': 11, 'num_categories': 23},
#   'V249': {'embedding_dim': 11, 'num_categories': 22},
#   'V183_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V88': {'embedding_dim': 4, 'num_categories': 3},
#   'V244': {'embedding_dim': 11, 'num_categories': 23},
#   'V195': {'embedding_dim': 9, 'num_categories': 17},
#   'V74': {'embedding_dim': 6, 'num_categories': 10},
#   'V111_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V67': {'embedding_dim': 6, 'num_categories': 10},
#   'id_19_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V227': {'embedding_dim': 16, 'num_categories': 38},
#   'V13_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V202_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_30': {'embedding_dim': 26, 'num_categories': 76},
#   'V43': {'embedding_dim': 6, 'num_categories': 10},
#   'V139_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_38': {'embedding_dim': 4, 'num_categories': 3},
#   'V148_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V161_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V140': {'embedding_dim': 14, 'num_categories': 32},
#   'V118': {'embedding_dim': 4, 'num_categories': 3},
#   'id_29': {'embedding_dim': 4, 'num_categories': 3},
#   'V15': {'embedding_dim': 6, 'num_categories': 9},
#   'V278_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V133_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_15': {'embedding_dim': 4, 'num_categories': 4},
#   'V43_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V75': {'embedding_dim': 4, 'num_categories': 2},
#   'V162_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V292': {'embedding_dim': 21, 'num_categories': 54},
#   'V188': {'embedding_dim': 13, 'num_categories': 28},
#   'V45_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V38': {'embedding_dim': 20, 'num_categories': 51},
#   'V333_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V286': {'embedding_dim': 5, 'num_categories': 7},
#   'V51_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V239': {'embedding_dim': 11, 'num_categories': 22},
#   'V54': {'embedding_dim': 4, 'num_categories': 2},
#   'V76_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V218_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'card5': {'embedding_dim': 30, 'num_categories': 96},
#   'V224': {'embedding_dim': 23, 'num_categories': 65},
#   'V168_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V170': {'embedding_dim': 19, 'num_categories': 48},
#   'V253_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V262': {'embedding_dim': 11, 'num_categories': 22},
#   'V171': {'embedding_dim': 22, 'num_categories': 60},
#   'V12_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V62': {'embedding_dim': 7, 'num_categories': 12},
#   'V120': {'embedding_dim': 4, 'num_categories': 4},
#   'id_10': {'embedding_dim': 22, 'num_categories': 59},
#   'V59_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V296': {'embedding_dim': 27, 'num_categories': 82},
#   'card6': {'embedding_dim': 4, 'num_categories': 4},
#   'V49': {'embedding_dim': 4, 'num_categories': 2},
#   'V149_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V201': {'embedding_dim': 21, 'num_categories': 56},
#   'V155_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V118_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V138_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V252_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V148': {'embedding_dim': 11, 'num_categories': 21},
#   'V64_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V98_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V39': {'embedding_dim': 9, 'num_categories': 16},
#   'V305': {'embedding_dim': 4, 'num_categories': 2},
#   'V70': {'embedding_dim': 4, 'num_categories': 2},
#   'V114': {'embedding_dim': 5, 'num_categories': 7},
#   'V44_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V209_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V234_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V339_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V302': {'embedding_dim': 9, 'num_categories': 17},
#   'V68': {'embedding_dim': 4, 'num_categories': 4},
#   'id_17_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V73': {'embedding_dim': 6, 'num_categories': 9},
#   'V46_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V185': {'embedding_dim': 12, 'num_categories': 25},
#   'V78': {'embedding_dim': 15, 'num_categories': 33},
#   'V262_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V18': {'embedding_dim': 8, 'num_categories': 15},
#   'V198': {'embedding_dim': 10, 'num_categories': 20},
#   'V288': {'embedding_dim': 5, 'num_categories': 8},
#   'V26_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V29': {'embedding_dim': 4, 'num_categories': 2},
#   'D12_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_36': {'embedding_dim': 4, 'num_categories': 3},
#   'V189': {'embedding_dim': 13, 'num_categories': 29},
#   'V298': {'embedding_dim': 26, 'num_categories': 77},
#   'V120_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V283_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V142_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V159_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V58_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V63_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V224_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V46': {'embedding_dim': 5, 'num_categories': 8},
#   'V140_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V210_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V332_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_11_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V221': {'embedding_dim': 23, 'num_categories': 63},
#   'id_10_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V56': {'embedding_dim': 17, 'num_categories': 39},
#   'id_32': {'embedding_dim': 4, 'num_categories': 5},
#   'V24': {'embedding_dim': 8, 'num_categories': 15},
#   'V36_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'P_emaildomain': {'embedding_dim': 22, 'num_categories': 60},
#   'V82_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V338_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V50_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V90': {'embedding_dim': 4, 'num_categories': 2},
#   'V213_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V216_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V112': {'embedding_dim': 6, 'num_categories': 9},
#   'V104_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V53': {'embedding_dim': 4, 'num_categories': 2},
#   'V79_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V74_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V60': {'embedding_dim': 8, 'num_categories': 15},
#   'V22': {'embedding_dim': 6, 'num_categories': 9},
#   'V153': {'embedding_dim': 10, 'num_categories': 18},
#   'V116_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V257_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V204_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V105_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V40': {'embedding_dim': 9, 'num_categories': 17},
#   'R_emaildomain': {'embedding_dim': 22, 'num_categories': 61},
#   'V135_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V41': {'embedding_dim': 4, 'num_categories': 3},
#   'V211_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V19': {'embedding_dim': 6, 'num_categories': 9},
#   'V108_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'addr1_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V301': {'embedding_dim': 8, 'num_categories': 13},
#   'V75_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V205_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V254_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V190': {'embedding_dim': 18, 'num_categories': 43},
#   'V103_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V89_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V12': {'embedding_dim': 4, 'num_categories': 2},
#   'id_14': {'embedding_dim': 12, 'num_categories': 26},
#   'V267_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V229': {'embedding_dim': 27, 'num_categories': 79},
#   'V250': {'embedding_dim': 10, 'num_categories': 19},
#   'V36': {'embedding_dim': 4, 'num_categories': 2},
#   'V248': {'embedding_dim': 11, 'num_categories': 22},
#   'V277_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V314_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V256_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V27_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V89': {'embedding_dim': 4, 'num_categories': 4},
#   'V62_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V281': {'embedding_dim': 10, 'num_categories': 20},
#   'D9': {'embedding_dim': 12, 'num_categories': 25},
#   'V328_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V32_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V237': {'embedding_dim': 15, 'num_categories': 33},
#   'id_09_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V252': {'embedding_dim': 12, 'num_categories': 24},
#   'V330_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V161': {'embedding_dim': 24, 'num_categories': 69},
#   'V91_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V124_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V163_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V261': {'embedding_dim': 17, 'num_categories': 40},
#   'D14_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V151': {'embedding_dim': 21, 'num_categories': 57},
#   'V221_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V158_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V228': {'embedding_dim': 19, 'num_categories': 49},
#   'V100_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V82': {'embedding_dim': 6, 'num_categories': 9},
#   'V184_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V334_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_04_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V163': {'embedding_dim': 29, 'num_categories': 89},
#   'V206_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V20': {'embedding_dim': 9, 'num_categories': 16},
#   'V81_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V110': {'embedding_dim': 5, 'num_categories': 8},
#   'V283': {'embedding_dim': 18, 'num_categories': 46},
#   'V259_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V157_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V242_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V323_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V245_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V22_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V207_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V176_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V248_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V55_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V95_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V19_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_12': {'embedding_dim': 4, 'num_categories': 3},
#   'V83_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V182': {'embedding_dim': 26, 'num_categories': 78},
#   'V109': {'embedding_dim': 5, 'num_categories': 8},
#   'V324_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V335_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_03_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V174': {'embedding_dim': 6, 'num_categories': 9},
#   'V197_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V260_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V141_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V107': {'embedding_dim': 4, 'num_categories': 2},
#   'V28': {'embedding_dim': 4, 'num_categories': 5},
#   'V145_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V47': {'embedding_dim': 6, 'num_categories': 10},
#   'V198_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V301_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V56_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V84_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V150_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V146_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V141': {'embedding_dim': 4, 'num_categories': 6},
#   'V243': {'embedding_dim': 17, 'num_categories': 40},
#   'V268_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V240_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V149': {'embedding_dim': 11, 'num_categories': 22},
#   'V185_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V183': {'embedding_dim': 18, 'num_categories': 43},
#   'V85_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V193': {'embedding_dim': 17, 'num_categories': 39},
#   'V34_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V71_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V55': {'embedding_dim': 9, 'num_categories': 16},
#   'V177_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V326_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V253': {'embedding_dim': 22, 'num_categories': 58},
#   'V215_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V153_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V90_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V201_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V186': {'embedding_dim': 17, 'num_categories': 40},
#   'V48': {'embedding_dim': 4, 'num_categories': 2},
#   'V20_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V126_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V237_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V147': {'embedding_dim': 11, 'num_categories': 22},
#   'V119_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V261_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V193_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V14_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V233_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V175_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V42': {'embedding_dim': 6, 'num_categories': 9},
#   'V72': {'embedding_dim': 7, 'num_categories': 12},
#   'V84': {'embedding_dim': 6, 'num_categories': 9},
#   'V156_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V16_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V236': {'embedding_dim': 17, 'num_categories': 40},
#   'V243_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V23_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V179_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V33_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V200': {'embedding_dim': 18, 'num_categories': 46},
#   'V200_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V191_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V123': {'embedding_dim': 8, 'num_categories': 14},
#   'V71': {'embedding_dim': 5, 'num_categories': 8},
#   'V169_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V296_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V39_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V100': {'embedding_dim': 10, 'num_categories': 18},
#   'V144_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V35': {'embedding_dim': 4, 'num_categories': 2},
#   'id_01': {'embedding_dim': 24, 'num_categories': 68},
#   'V223': {'embedding_dim': 10, 'num_categories': 18},
#   'D8_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V329_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V117': {'embedding_dim': 4, 'num_categories': 3},
#   'V194': {'embedding_dim': 6, 'num_categories': 9},
#   'V102_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V242': {'embedding_dim': 11, 'num_categories': 22},
#   'V27': {'embedding_dim': 4, 'num_categories': 5},
#   'V49_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V147_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V70_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V212_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V57_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V186_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_09': {'embedding_dim': 17, 'num_categories': 42},
#   'V88_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V28_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V85': {'embedding_dim': 6, 'num_categories': 9},
#   'addr2': {'embedding_dim': 24, 'num_categories': 67},
#   'V225': {'embedding_dim': 14, 'num_categories': 32},
#   'V246_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V94': {'embedding_dim': 4, 'num_categories': 3},
#   'V182_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V154': {'embedding_dim': 10, 'num_categories': 18},
#   'V175': {'embedding_dim': 8, 'num_categories': 13},
#   'V26': {'embedding_dim': 7, 'num_categories': 12},
#   'V67_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V196_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V220': {'embedding_dim': 12, 'num_categories': 26},
#   'D10_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V146': {'embedding_dim': 11, 'num_categories': 21},
#   'V69_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V214_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V132_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V105': {'embedding_dim': 26, 'num_categories': 78},
#   'card4': {'embedding_dim': 4, 'num_categories': 5},
#   'V230': {'embedding_dim': 23, 'num_categories': 63},
#   'V272_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V297': {'embedding_dim': 8, 'num_categories': 13},
#   'V91': {'embedding_dim': 4, 'num_categories': 2},
#   'V167_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V270_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V98': {'embedding_dim': 6, 'num_categories': 10},
#   'V154_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V31_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V192_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V57': {'embedding_dim': 5, 'num_categories': 8},
#   'V101_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V172': {'embedding_dim': 14, 'num_categories': 32},
#   'V328': {'embedding_dim': 9, 'num_categories': 17},
#   'V266_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V115_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V50': {'embedding_dim': 5, 'num_categories': 7},
#   'V152_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V228_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V64': {'embedding_dim': 6, 'num_categories': 9},
#   'V337_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_35': {'embedding_dim': 4, 'num_categories': 3},
#   'V194_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V32': {'embedding_dim': 9, 'num_categories': 16},
#   'V138': {'embedding_dim': 10, 'num_categories': 20},
#   'V289_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'card5_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V122_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V287': {'embedding_dim': 8, 'num_categories': 15},
#   'V107_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V73_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V110_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V300': {'embedding_dim': 8, 'num_categories': 13},
#   'V81': {'embedding_dim': 10, 'num_categories': 20},
#   'V99': {'embedding_dim': 18, 'num_categories': 45},
#   'V195_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V144': {'embedding_dim': 23, 'num_categories': 64},
#   'V93': {'embedding_dim': 6, 'num_categories': 9},
#   'V256': {'embedding_dim': 17, 'num_categories': 39},
#   'V152': {'embedding_dim': 16, 'num_categories': 38},
#   'V304': {'embedding_dim': 9, 'num_categories': 17},
#   'V273_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'D13_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V125_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V244_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V291': {'embedding_dim': 23, 'num_categories': 63},
#   'V196': {'embedding_dim': 17, 'num_categories': 40},
#   'V96_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V208_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V217_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V23': {'embedding_dim': 8, 'num_categories': 15},
#   'V282_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V184': {'embedding_dim': 9, 'num_categories': 16},
#   'M4': {'embedding_dim': 4, 'num_categories': 4},
#   'V251': {'embedding_dim': 10, 'num_categories': 19},
#   'V173': {'embedding_dim': 6, 'num_categories': 9},
#   'V222_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_04': {'embedding_dim': 8, 'num_categories': 15},
#   'id_18': {'embedding_dim': 8, 'num_categories': 15},
#   'V29_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V330': {'embedding_dim': 20, 'num_categories': 51},
#   'V264_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'ProductCD': {'embedding_dim': 4, 'num_categories': 5},
#   'V191': {'embedding_dim': 11, 'num_categories': 23},
#   'V21': {'embedding_dim': 5, 'num_categories': 7},
#   'V263_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V86_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V336_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V197': {'embedding_dim': 8, 'num_categories': 14},
#   'id_13': {'embedding_dim': 20, 'num_categories': 50},
#   'D15_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V16': {'embedding_dim': 9, 'num_categories': 16},
#   'id_37': {'embedding_dim': 4, 'num_categories': 3},
#   'id_13_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V13': {'embedding_dim': 4, 'num_categories': 2},
#   'V226_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V60_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V254': {'embedding_dim': 17, 'num_categories': 40},
#   'V38_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V313_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V58': {'embedding_dim': 7, 'num_categories': 12},
#   'V245': {'embedding_dim': 18, 'num_categories': 43},
#   'V93_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'C5': {'embedding_dim': 4, 'num_categories': 2},
#   'V299': {'embedding_dim': 19, 'num_categories': 47},
#   'id_14_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V281_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V121': {'embedding_dim': 4, 'num_categories': 4},
#   'V247': {'embedding_dim': 10, 'num_categories': 19},
#   'V113_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V285': {'embedding_dim': 18, 'num_categories': 45},
#   'id_32_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V125': {'embedding_dim': 8, 'num_categories': 14},
#   'V199_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_05_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V30_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V241': {'embedding_dim': 4, 'num_categories': 5},
#   'V131_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V180_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V114_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V52': {'embedding_dim': 6, 'num_categories': 10},
#   'V87': {'embedding_dim': 13, 'num_categories': 29},
#   'V66': {'embedding_dim': 6, 'num_categories': 9},
#   'V117_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V119': {'embedding_dim': 4, 'num_categories': 3},
#   'V53_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V106': {'embedding_dim': 20, 'num_categories': 51},
#   'D1_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V21_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V72_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V265_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V172_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_28': {'embedding_dim': 4, 'num_categories': 3},
#   'V78_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V160_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V116': {'embedding_dim': 5, 'num_categories': 7},
#   'V174_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'D6_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V77': {'embedding_dim': 13, 'num_categories': 29},
#   'DeviceType': {'embedding_dim': 4, 'num_categories': 3},
#   'V128_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V113': {'embedding_dim': 6, 'num_categories': 9},
#   'V31': {'embedding_dim': 6, 'num_categories': 9},
#   'V61_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V255': {'embedding_dim': 15, 'num_categories': 35},
#   'V225_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V230_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V325': {'embedding_dim': 6, 'num_categories': 10},
#   'V235_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_20_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V65': {'embedding_dim': 4, 'num_categories': 3},
#   'V222': {'embedding_dim': 23, 'num_categories': 65},
#   'V54_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V61': {'embedding_dim': 5, 'num_categories': 8},
#   'V79': {'embedding_dim': 6, 'num_categories': 9},
#   'V99_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V189_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V271_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V290': {'embedding_dim': 16, 'num_categories': 37},
#   'V124': {'embedding_dim': 8, 'num_categories': 14},
#   'V41_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V171_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V325_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V40_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V127_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V229_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V139': {'embedding_dim': 14, 'num_categories': 32},
#   'V326': {'embedding_dim': 18, 'num_categories': 44},
#   'V24_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V238': {'embedding_dim': 11, 'num_categories': 22},
#   'V34': {'embedding_dim': 7, 'num_categories': 12},
#   'V250_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V166_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V142': {'embedding_dim': 5, 'num_categories': 8},
#   'V232_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V289': {'embedding_dim': 6, 'num_categories': 10},
#   'V69': {'embedding_dim': 4, 'num_categories': 2},
#   'V260': {'embedding_dim': 6, 'num_categories': 10},
#   'V47_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V282': {'embedding_dim': 13, 'num_categories': 29},
#   'id_16': {'embedding_dim': 4, 'num_categories': 3},
#   'V25_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V288_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V37': {'embedding_dim': 19, 'num_categories': 48},
#   'V52_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V68_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V123_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V181': {'embedding_dim': 11, 'num_categories': 22},
#   'V97_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V275_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V143_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V246': {'embedding_dim': 18, 'num_categories': 43},
#   'V249_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V255_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_05': {'embedding_dim': 29, 'num_categories': 88},
#   'D4_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V327': {'embedding_dim': 10, 'num_categories': 18},
#   'V187_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V315_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V66_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V165_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V33': {'embedding_dim': 5, 'num_categories': 7},
#   'V235': {'embedding_dim': 11, 'num_categories': 22},
#   'V258': {'embedding_dim': 24, 'num_categories': 67},
#   'V188_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V284': {'embedding_dim': 6, 'num_categories': 10},
#   'V80': {'embedding_dim': 10, 'num_categories': 20},
#   'V77_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V227_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V14': {'embedding_dim': 4, 'num_categories': 3},
#   'V94_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V251_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V180': {'embedding_dim': 27, 'num_categories': 80},
#   'V259': {'embedding_dim': 22, 'num_categories': 60},
#   'V274_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V199': {'embedding_dim': 18, 'num_categories': 46},
#   'V170_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V257': {'embedding_dim': 19, 'num_categories': 49},
#   'V83': {'embedding_dim': 6, 'num_categories': 9},
#   'V115': {'embedding_dim': 5, 'num_categories': 7},
#   'V15_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V129_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V322_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V329': {'embedding_dim': 26, 'num_categories': 78},
#   'id_03': {'embedding_dim': 11, 'num_categories': 23},
#   'V111': {'embedding_dim': 6, 'num_categories': 9},
#   'V151_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V276_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V169': {'embedding_dim': 10, 'num_categories': 20},
#   'V42_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V106_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V181_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V92': {'embedding_dim': 6, 'num_categories': 9},
#   'card3_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V192': {'embedding_dim': 18, 'num_categories': 46},
#   'V104': {'embedding_dim': 9, 'num_categories': 17},
#   'V220_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V173_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V269_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V238_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V44': {'embedding_dim': 19, 'num_categories': 49},
#   'V108': {'embedding_dim': 5, 'num_categories': 8},
#   'V112_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V121_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V240': {'embedding_dim': 5, 'num_categories': 7},
#   'V86': {'embedding_dim': 13, 'num_categories': 29},
#   'V226': {'embedding_dim': 27, 'num_categories': 81},
#   'V331_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_18_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'addr2_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V134_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V190_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V136_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V164_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V59': {'embedding_dim': 8, 'num_categories': 14},
#   'V37_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V130_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V76': {'embedding_dim': 4, 'num_categories': 2},
#   'V25': {'embedding_dim': 5, 'num_categories': 7},
#   'V241_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V65_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'C9': {'embedding_dim': 4, 'num_categories': 2},
#   'V258_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V87_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V17': {'embedding_dim': 8, 'num_categories': 15},
#   'V239_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V303': {'embedding_dim': 11, 'num_categories': 22},
#   'V231_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'C3': {'embedding_dim': 12, 'num_categories': 24},
#   'V158': {'embedding_dim': 11, 'num_categories': 23},
#   'V45': {'embedding_dim': 19, 'num_categories': 49},
#   'V327_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V157': {'embedding_dim': 11, 'num_categories': 21},
#   'V300_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'V219_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'id_06_col_na_binary': {'embedding_dim': 4, 'num_categories': 2},
#   'card2_col_na_binary': {'embedding_dim': 4, 'num_categories': 2}},
#  'real_features': {'C1',
#   'C10',
#   'C11',
#   'C12',
#   'C13',
#   'C14',
#   'C2',
#   'C4',
#   'C6',
#   'C7',
#   'C8',
#   'D1',
#   'D10',
#   'D12',
#   'D13',
#   'D14',
#   'D15',
#   'D4',
#   'D6',
#   'D8',
#   'TransactionAmt',
#   'TransactionDT',
#   'TransactionID',
#   'Unnamed: 0',
#   'V101',
#   'V102',
#   'V103',
#   'V126',
#   'V127',
#   'V128',
#   'V129',
#   'V130',
#   'V131',
#   'V132',
#   'V133',
#   'V134',
#   'V135',
#   'V136',
#   'V137',
#   'V143',
#   'V145',
#   'V150',
#   'V159',
#   'V160',
#   'V162',
#   'V164',
#   'V165',
#   'V166',
#   'V167',
#   'V168',
#   'V177',
#   'V178',
#   'V179',
#   'V187',
#   'V202',
#   'V203',
#   'V204',
#   'V205',
#   'V206',
#   'V207',
#   'V208',
#   'V209',
#   'V210',
#   'V211',
#   'V212',
#   'V213',
#   'V214',
#   'V215',
#   'V216',
#   'V217',
#   'V218',
#   'V219',
#   'V231',
#   'V232',
#   'V233',
#   'V234',
#   'V263',
#   'V264',
#   'V265',
#   'V266',
#   'V267',
#   'V268',
#   'V269',
#   'V270',
#   'V271',
#   'V272',
#   'V273',
#   'V274',
#   'V275',
#   'V276',
#   'V277',
#   'V278',
#   'V279',
#   'V280',
#   'V293',
#   'V294',
#   'V295',
#   'V306',
#   'V307',
#   'V308',
#   'V309',
#   'V310',
#   'V311',
#   'V312',
#   'V313',
#   'V314',
#   'V315',
#   'V316',
#   'V317',
#   'V318',
#   'V319',
#   'V320',
#   'V321',
#   'V322',
#   'V323',
#   'V324',
#   'V331',
#   'V332',
#   'V333',
#   'V334',
#   'V335',
#   'V336',
#   'V337',
#   'V338',
#   'V339',
#   'V95',
#   'V96',
#   'V97',
#   'addr1',
#   'card1',
#   'card2',
#   'id_02',
#   'id_06',
#   'id_11',
#   'id_19',
#   'id_20'},
#  'input_concat_vector_size': 4293,
#  'high_var_objects': {'DeviceInfo', 'id_31', 'id_33'}}

# %%
params['input_concat_vector_size']
# Out:
# 2700

# %%
def get_features(data):
    x = []
    y = []

    rows = data.dataset.data.shape[0]
    columns = params['input_concat_vector_size']

    for batch in tqdm(data):
        model(batch)
        x.append(model.vector.detach().numpy())
        y.append(batch["target"].numpy())

    x = np.concatenate(x, axis=0)
    y = np.concatenate(y, axis=0)
    print(x.shape)
    print(f'Dimensions match: {x.shape == (rows, columns)}')
    return x,y

# %%
train_x, train_y = get_features(train_set)
np.save('train_x.pkl',train_x)
np.save('train_y.pkl',train_y)
# Out:
# 100%|██████████| 170/170 [05:12<00:00,  1.84s/it]
# (86701, 2700)
# Dimensions match: True

# %%
val_x, val_y = get_features(val_set)
np.save('val_x.pkl',val_x)
np.save('val_y.pkl',val_y)
# Out:
# 100%|██████████| 57/57 [01:52<00:00,  1.98s/it]
# (28795, 2700)
# Dimensions match: True
